# %%
import pandas as pd
from dataclasses import dataclass, field
from typing import Union, Dict, Optional
from importlib import resources
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
@dataclass
class DataCatalog():
    """
    Data catalog which makes it easy to find, extract, use, and share CryptoDataPy's datasets.

    Parameters
    ----------
    data_sources: str
        Name of data source, e.g. 'cryptocompare', 'coinmetrics', 'glassnode', etc.

    """
    data_sources: Dict = field(default_factory=lambda: {
        'ccxt': 'https://github.com/ccxt/ccxt',
        'cryptocompare': 'https://min-api.cryptocompare.com/documentation',
        'coinmetrics': 'https://docs.coinmetrics.io/info/markets',
        'glassnode': 'https://glassnode.com/',
        'tiingo': 'https://api.tiingo.com/products/crypto-api',
        'alpha vantage': 'https://www.alphavantage.co/documentation/',
        'yahoo finance': 'https://finance.yahoo.com/',
        'investpy': 'https://investpy.readthedocs.io/',
        'dbnomics': 'https://db.nomics.world/providers',
        'fred': 'https://fred.stlouisfed.org/'
    })

    @staticmethod
    def get_tickers_metadata(tickers: Optional[Union[str, list[str]]] = None, country_id_2: Optional[str] = None,
                             country_id_3: Optional[str] = None, country_name: Optional[str] = None, 
                             agg: Optional[str] = None, cat: Optional[str] = None, subcat: Optional[str] = None, 
                             mkt_type: Optional[str] = None, quote_ccy: Optional[str] = None, as_list=False) -> pd.DataFrame():
        """
        Gets ticker metadata. Excludes individual equity tickers.

        Parameters
        ----------
        tickers: str or list, optional, default None
            Tickers for which to get metadata.
        country_id_2: str, optional, default None
            Country code for which to filter tickers, ISO 3166-1 alpha-2 format.
        country_id_3: str, optional, default None
            Country code for which to filter tickers, ISO 3166-1 alpha-3 format.
        country_name: str, optional, default None
            Country name for which to filer tickers.
        agg: str, {'DM', 'EM', 'WL', 'Euro zone'}, optional, default None
            Country aggregate.
        cat: str, {'crypto', 'fx', 'cmdty', 'eqty', 'rates', 'bonds', 'credit', 'macro', 'alt'}
            Tickers category.
        subcat: str, { 'spot rate', 'index', 'effective exchange rate', 'yield', 'swap rate', 'real yield', 
                       'inflation', 'spread', 'etf', 'vol', 'reit', 'industrial metals', 'grains', 'energy', 'softs',
                       'livestock', 'precious metals', 'growth', 'unemployment', 'money', 'credit', 'property'},
                       optional, default None
            Tickers subcategory.
        mkt_type: str, {'spot', 'etf', 'perpetual_future', 'future', 'swap', 'option'}, optional, default None
            Market type, e.g. 'spot ', 'future', 'perpetual_future', 'option'.
        quote_ccy: str,  optional, default None
            Quote currency for base asset, e.g. 'GBP' for EURGBP, 'USD' for BTCUSD (bitcoin in dollars), etc.

        Returns
        -------
        tickers_df: pd.DataFrame
            DataFrame with tickers metadata.
        """
        # get tickers csv file
        with resources.path('cryptodatapy.conf', 'tickers.csv') as f:
            tickers_path = f
        tickers_df = pd.read_csv(tickers_path, index_col=0, encoding='latin1')

        # filter by tickers
        if tickers is not None:
            tickers_df = tickers_df.loc[tickers, :]
        # filter by country id 2
        if country_id_2 is not None:
            tickers_df = tickers_df[tickers_df.country_id_2 == country_id_2.upper()]
        # filter by country id 3
        if country_id_3 is not None:
            tickers_df = tickers_df[tickers_df.country_id_3 == country_id_3.upper()]
        # filter by country name
        if country_name is not None:
            tickers_df = tickers_df[tickers_df.country_name == country_name.title()]
        # filter by aggregate
        if agg is not None:
            tickers_df = tickers_df[tickers_df['agg'] == agg]
        # filter by category
        if cat is not None:
            tickers_df = tickers_df[tickers_df.category == cat.lower()]
        # filter by sub category
        if subcat is not None:
            tickers_df = tickers_df[tickers_df.subcategory == subcat.lower()]
        # filter by mkt type
        if mkt_type is not None:
            tickers_df = tickers_df[tickers_df.mkt_type == mkt_type.lower()]
        # filter by quote ccy
        if quote_ccy is not None:
            tickers_df = tickers_df[tickers_df.quote_ccy == quote_ccy.upper()]
        # as list
        if as_list:
            tickers_df = list(set(tickers_df.index.to_list()))

        return tickers_df

    @staticmethod
    def search_tickers(by_col: str = Optional[None], keyword: Optional[str] = None) -> pd.DataFrame():
        """
        Parameters
        ----------
        by_col: str, optional, default None
            Column by which to search.
        keyword: str, optional, default None
            Keyword for which to search.

        Returns
        -------
        tickers_df: pd.DataFrame
            DataFrame with tickers metadata.
        """
        # get tickers csv file
        with resources.path('cryptodatapy.conf', 'tickers.csv') as f:
            tickers_path = f
        tickers_df = pd.read_csv(tickers_path, index_col=0, encoding='latin1')

        if by_col is None or keyword is None:
            raise ValueError("Provide column name and keyword to search for.")
        else:
            tickers_df = tickers_df[tickers_df[by_col].str.contains(keyword)]

        return tickers_df

    @staticmethod
    def get_fields_metadata(fields: Optional[Union[str, list[str]]] = None, name: Optional[str] = None,
                            cat: Optional[str] = None, subcat: Optional[str] = None, as_list=False) -> pd.DataFrame():
        """
        Gets fields metadata.

        Parameters
        ----------
        fields: str or list, optional, default None
            Field ids for which to get metadata.
        name: str, optional, default None
            Name of fields for which to get metadata.
        cat: str, {'all', 'market', 'on-chain', 'off-chain'}
            Fields category, i.e. type of data.
        subcat: str, optional, default None
            Fields subcategory.

        Returns
        -------
        fields_df: pd.DataFrame
            DataFrame with fields metadata.
        """
        # get fields csv file
        with resources.path('cryptodatapy.conf', 'fields.csv') as f:
            fields_path = f
        fields_df = pd.read_csv(fields_path, index_col=0, encoding='latin1')

        # filter by field ids
        if fields is not None:
            fields_df = fields_df.loc[fields, :]
        # filter by field name
        if name is not None:
            fields_df = fields_df[fields_df.name == name.lower()]
        # filter by category
        if cat is not None:
            fields_df = fields_df[fields_df.category == cat.lower()]
        # filter by sub category
        if subcat is not None:
            fields_df = fields_df[fields_df.subcategory == subcat.lower()]
        # as list
        if as_list:
            fields_df = list(set(fields_df.index.to_list()))

        return fields_df

    @staticmethod
    def search_fields(by_col: Optional[str] = None, keyword: Optional[str] = None) -> pd.DataFrame():
        """
        Parameters
        ----------
        by_col: str, optional, default None
            Column by which to search.
        keyword: str, optional, default None
            Keyword for which to search.

        Returns
        -------
        fields_df: pd.DataFrame
            DataFrame with fields metadata.
        """
        # get fields csv file
        with resources.path('cryptodatapy.conf', 'fields.csv') as f:
            fields_path = f
        fields_df = pd.read_csv(fields_path, index_col=0, encoding='latin1')

        if by_col is None or keyword is None:
            raise ValueError("Provide column name and keyword to search for.")
        else:
            fields_df = fields_df[fields_df[by_col].str.contains(keyword)]

        return fields_df

    @staticmethod
    def scrape_stablecoins(source: str = 'coingecko', rank_by: str = 'mkt_cap', 
                           as_list=False) -> Union[pd.DataFrame, list]:
        """
        Web scrapes stablecoin information from CoinGecko or CoinMarketCap websites.

        Parameters
        ----------
        source: str, {'coinmarketcap', 'coingecko'}, default 'coingecko'
            Website from which to scrape list of stablecoins.
        rank_by: str, default 'mkt_cap'
            Metrics by which to rank stablecoins.
        as_list, bool, default 'False'
            Return stablecoins tickers as list.

        Returns
        -------
        sc: Pd.Dataframe or list
            DataFrame with stablecoin info or list of stablecoin tickers.
        """
        # chrome driver
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        # url
        if source == 'coinmarketcap':
            url = 'http://coinmarketcap.com/view/stablecoin/'
        elif source == 'coingecko':
            url = 'https://www.coingecko.com/en/categories/stablecoins'
        # get url
        driver.get(url)
        # manage wait time
        driver.implicitly_wait(60)
        # page source
        html = driver.page_source
        # get tables
        tables = pd.read_html(html)
        df = tables[0]
        # close driver
        driver.close()

        # wrangle table 
        if source == 'coinmarketcap':
            df['name'] = df.Name.str.split('(\\d+)', 1, expand=True)[0]
            df['ticker'] = df.Name.str.split('(\\d+)', 1, expand=True)[2]
            df['price'] = df.Price.str.split("$", 1, expand=True)[1].astype(float)
            df['24h_%_chg'] = df['24h %'].str.split('%', 1, expand=True)[0].astype(float)/100
            df['7d_%_chg'] = df['7d %'].str.split('%', 1, expand=True)[0].astype(float)/100
            df['mkt_cap'] = df['Market Cap'].str.split('$',2, expand=True)[2].str.replace(',','', regex=False).astype(float)
            df['volume_24h'] = df['Volume(24h)'].str.split(" ", 1, expand=True)[0].str.replace("$", "", regex=False).str.replace(",", "", regex=False).astype(float)    
            df['circ_suppkly'] = df['Circulating Supply'].str.split(' ',1, expand=True)[0].str.replace(",","", regex=False).astype(float)   
            # reorder cols
            df = df.loc[:,'name':]
            # set index
            df.set_index('ticker', inplace=True)

        elif source == 'coingecko':

            df['name'] = df.Coin.str.split(" ", 4, expand=True)[0] + " " + df.Coin.str.split(" ", 4, expand=True)[1]
            tickers_list = []
            for row in df.Coin.str.split(" ", 4, expand=True).iterrows():
                tickers_list.append(row[1].dropna().iloc[-1])
            df['ticker'] = tickers_list
            df['price'] = df.Price.str.split("$", 0, expand=True)[1].str.replace(",", "").astype(float)
            df['mkt_cap'] = df['Market Capitalization'].str.split('$', 1, expand=True)[1].str.replace(',', '').astype(float)
            df['24h_volume'] = df['24h Volume'].str.split("$", 1, expand=True)[1].str.replace(",","").astype(float)
            # reorder cols
            df = df.loc[:, 'name':]
            # set index
            df.set_index('ticker', inplace=True)

        # rank by
        if rank_by is not None:
            sc = df.sort_values(by=rank_by, ascending=False)
        else:
            sc = df

        # tickers list
        if as_list:
            # remove duplicated tickers
             sc = df.loc[df.index.drop_duplicates().to_list()].index.to_list()

        return sc

# %%
DataCatalog().data_sources
# Out:
# {'ccxt': 'https://github.com/ccxt/ccxt',
#  'cryptocompare': 'https://min-api.cryptocompare.com/documentation',
#  'coinmetrics': 'https://docs.coinmetrics.io/info/markets',
#  'glassnode': 'https://glassnode.com/',
#  'tiingo': 'https://api.tiingo.com/products/crypto-api',
#  'alpha vantage': 'https://www.alphavantage.co/documentation/',
#  'yahoo finance': 'https://finance.yahoo.com/',
#  'investpy': 'https://investpy.readthedocs.io/',
#  'dbnomics': 'https://db.nomics.world/providers',
#  'fred': 'https://fred.stlouisfed.org/'}

# %%
dc = DataCatalog()

# %%
df = dc.get_tickers_metadata(cat='rates', subcat='inflation', country_id_2='US')

# %%
df = dc.get_tickers_metadata(cat='crypto', subcat='stablecoin')

# %%
df
# Out:
#                       name description  url country_id_2 country_id_3  \
# ticker
# USDT           Tether USDT         NaN  NaN           WL          WLD
# USDC              USD Coin         NaN  NaN           WL          WLD
# BUSD           Binance USD         NaN  NaN           WL          WLD
# DAI                Dai DAI         NaN  NaN           WL          WLD
# FRAX             Frax FRAX         NaN  NaN           WL          WLD
# ...                    ...         ...  ...          ...          ...
# JCHF      Jarvis Synthetic         NaN  NaN           WL          WLD
# XUSD    xDollar Stablecoin         NaN  NaN           WL          WLD
# IRON              Iron BSC         NaN  NaN           WL          WLD
# IRON             Iron IRON         NaN  NaN           WL          WLD
# CADC              CAD Coin         NaN  NaN           WL          WLD
#
#        country_name agg category subcategory mkt_type frequency tenor  \
# ticker
# USDT          World  WL   crypto  stablecoin     spot      tick   NaN
# USDC          World  WL   crypto  stablecoin     spot      tick   NaN
# BUSD          World  WL   crypto  stablecoin     spot      tick   NaN
# DAI           World  WL   crypto  stablecoin     spot      tick   NaN
# FRAX          World  WL   crypto  stablecoin     spot      tick   NaN
# ...             ...  ..      ...         ...      ...       ...   ...
# JCHF          World  WL   crypto  stablecoin     spot      tick   NaN
# XUSD          World  WL   crypto  stablecoin     spot      tick   NaN
# IRON          World  WL   crypto  stablecoin     spot      tick   NaN
# IRON          World  WL   crypto  stablecoin     spot      tick   NaN
# CADC          World  WL   crypto  stablecoin     spot      tick   NaN
#
#                                         unit quote_ccy investpy_id tiingo_id  \
# ticker
# USDT    fiat currency per unit of stablecoin       NaN         NaN       NaN
# USDC    fiat currency per unit of stablecoin       NaN         NaN       NaN
# BUSD    fiat currency per unit of stablecoin       NaN         NaN       NaN
# DAI     fiat currency per unit of stablecoin       NaN         NaN       NaN
# FRAX    fiat currency per unit of stablecoin       NaN         NaN       NaN
# ...                                      ...       ...         ...       ...
# JCHF    fiat currency per unit of stablecoin       NaN         NaN       NaN
# XUSD    fiat currency per unit of stablecoin       NaN         NaN       NaN
# IRON    fiat currency per unit of stablecoin       NaN         NaN       NaN
# IRON    fiat currency per unit of stablecoin       NaN         NaN       NaN
# CADC    fiat currency per unit of stablecoin       NaN         NaN       NaN
#
#        dbnomics_id fred_id  alfred_id philly_fed_id
# ticker
# USDT           NaN     NaN        NaN           NaN
# USDC           NaN     NaN        NaN           NaN
# BUSD           NaN     NaN        NaN           NaN
# DAI            NaN     NaN        NaN           NaN
# FRAX           NaN     NaN        NaN           NaN
# ...            ...     ...        ...           ...
# JCHF           NaN     NaN        NaN           NaN
# XUSD           NaN     NaN        NaN           NaN
# IRON           NaN     NaN        NaN           NaN
# IRON           NaN     NaN        NaN           NaN
# CADC           NaN     NaN        NaN           NaN
#
# [86 rows x 20 columns]

# %%
dc.search_tickers(by_col='name', keyword='USD Coin')
# Out:
#             name description  url country_id_2 country_id_3 country_name agg  \
# ticker
# USDC    USD Coin         NaN  NaN           WL          WLD        World  WL
#
#        category subcategory mkt_type frequency tenor  \
# ticker
# USDC     crypto  stablecoin     spot      tick   NaN
#
#                                         unit quote_ccy investpy_id tiingo_id  \
# ticker
# USDC    fiat currency per unit of stablecoin       NaN         NaN       NaN
#
#        dbnomics_id fred_id  alfred_id philly_fed_id
# ticker
# USDC           NaN     NaN        NaN           NaN

# %%
df = dc.get_fields_metadata(cat='on-chain')

# %%
df
# Out:
#                                                                 name  \
# id
# add_act                                             active addresses
# add_act_new                                            new addresses
# add_act_sent                                   active addresses sent
# add_act_rec                                active addresses received
# add_tot                                          total address count
# add_pos_bal                         addresses with positive balance
# add_zero_bal                       addresses with zero balance count
# tx_count                                          transactions count
# tx_rate                                            transactions rate
# tx_bytes_mean                                       transaction size
# tx_fee_mean                                    mean transaction fee
# tx_fee_mean_usd                          mean transaction fee in usd
# tfr_val                                              transfers value
# tfr_val_mean                                    mean transfers value
# velocity_1y                                                 velocity
# tx_>100k_usd                transactions larger than 100k usd count
# tx_tot                                     total transactions count
# utxo                                     unspent transaction outputs
# utxo_created                     unspent transaction outputs created
# utxo_spent                                 spent transaction outputs
# utxo_val_created                      newly created asset units utxo
# utxo_val_spent              asset units in spent transaction outputs
# utxo_val_created_mean            mean newly created asset units utxo
# utxo_val_spent_mean    mean asset units in spent transaction outputs
# hashrate                                                   hash rate
# diff_last                                   difficulty of last block
# diff_mean                                 mean difficulty of a block
# block_height                                            block height
# block_size_mean                                      mean block size
# block_time_mean                                      mean block time
# miner_rev                                              miner revenue
# miner_rev_usd                                   miner revenue in usd
# miner_rev_fees                                         miner revenue
# miner_rev_fees_usd                           miner revenue from fees
# miner_rev_block_rwd                 miner revenue from block rewards
# miner_rev_total_usd                       total miner revenue in usd
# supply_circ                                       circulating supply
# supply_ff                                          free float supply
# issuance                                                   issuance
# supply_act_pct_1y           pecent of supply active in the past year
# stocks_to_flow                                  stocks-to-flow ratio
# sopr                                        spent output price ratio
#
#                                                              description  \
# id
# add_act                number of unique addresses that were active in...
# add_act_new            number of new unique addresses that were creat...
# add_act_sent           number of unique addresses that were active in...
# add_act_rec            number of unique addresses that were active in...
# add_tot                number of unique addresses in the network  at ...
# add_pos_bal            number of unique addresses  with positive bala...
# add_zero_bal           number of unique addresses  with zero balance ...
# tx_count               number of transactions in the network within t...
# tx_rate                               number of transactions per second
# tx_bytes_mean             mean size of transactions within time interval
# tx_fee_mean                mean fee per transaction within time interval
# tx_fee_mean_usd        mean fee per transaction within time interval,...
# tfr_val                number of units of asset transferred in the ne...
# tfr_val_mean           mean transfer value in the network within time...
# velocity_1y            ratio of transfer value over the past year ove...
# tx_>100k_usd           number of transactions in the network larger t...
# tx_tot                 number of transactions in the network at the e...
# utxo                   total transaction output that can be used as i...
# utxo_created               number of created unspent transaction outputs
# utxo_spent                           number of spent transaction outputs
# utxo_val_created          numbrer of assets units in newly created UTXOs
# utxo_val_spent         numbrer of assets units in spent transaction o...
# utxo_val_created_mean  mean numbrer of assets units in newly created ...
# utxo_val_spent_mean    mean numbrer of assets units in spent transact...
# hashrate               mean number of hashes per second produced by t...
# diff_last              number of hashes required to mine the last blo...
# diff_mean              mean number of hashes required to mine a block...
# block_height           number of blocks created and included in the m...
# block_size_mean         mean size of blocks created within time interval
# block_time_mean        mean time for block to be created within time ...
# miner_rev              total miner revenue, fees plus newly minted co...
# miner_rev_usd          total miner revenue, fees plus newly minted co...
# miner_rev_fees         miner revenue dervied from fees within time in...
# miner_rev_fees_usd     miner revenue dervied from fees within time in...
# miner_rev_block_rwd    miner revenue dervied from block rewards withi...
# miner_rev_total_usd    total miner revenue, fees plus newly minted co...
# supply_circ            total number of asset units issued/created on ...
# supply_ff              total number of asset units issued/created on ...
# issuance               number of new asset units issues within time i...
# supply_act_pct_1y      percentage of current supply that has been act...
# stocks_to_flow         ratio of the circulating supply to the newly i...
# sopr                   ratio of the sum of spent value over the sum o...
#
#                        category   subcategory        freq  \
# id
# add_act                on-chain     addresses  d, w, m, q
# add_act_new            on-chain     addresses  d, w, m, q
# add_act_sent           on-chain     addresses  d, w, m, q
# add_act_rec            on-chain     addresses  d, w, m, q
# add_tot                on-chain     addresses  d, w, m, q
# add_pos_bal            on-chain     addresses  d, w, m, q
# add_zero_bal           on-chain     addresses  d, w, m, q
# tx_count               on-chain  transactions  d, w, m, q
# tx_rate                on-chain  transactions  d, w, m, q
# tx_bytes_mean          on-chain  transactions  d, w, m, q
# tx_fee_mean            on-chain  transactions  d, w, m, q
# tx_fee_mean_usd        on-chain  transactions  d, w, m, q
# tfr_val                on-chain  transactions  d, w, m, q
# tfr_val_mean           on-chain  transactions  d, w, m, q
# velocity_1y            on-chain  transactions  d, w, m, q
# tx_>100k_usd           on-chain  transactions  d, w, m, q
# tx_tot                 on-chain  transactions  d, w, m, q
# utxo                   on-chain  transactions  d, w, m, q
# utxo_created           on-chain  transactions  d, w, m, q
# utxo_spent             on-chain  transactions  d, w, m, q
# utxo_val_created       on-chain  transactions  d, w, m, q
# utxo_val_spent         on-chain  transactions  d, w, m, q
# utxo_val_created_mean  on-chain  transactions  d, w, m, q
# utxo_val_spent_mean    on-chain  transactions  d, w, m, q
# hashrate               on-chain        mining  d, w, m, q
# diff_last              on-chain        mining  d, w, m, q
# diff_mean              on-chain        mining  d, w, m, q
# block_height           on-chain        mining  d, w, m, q
# block_size_mean        on-chain        mining  d, w, m, q
# block_time_mean        on-chain        mining  d, w, m, q
# miner_rev              on-chain        mining  d, w, m, q
# miner_rev_usd          on-chain        mining  d, w, m, q
# miner_rev_fees         on-chain        mining  d, w, m, q
# miner_rev_fees_usd     on-chain        mining  d, w, m, q
# miner_rev_block_rwd    on-chain        mining  d, w, m, q
# miner_rev_total_usd    on-chain        mining  d, w, m, q
# supply_circ            on-chain        supply  d, w, m, q
# supply_ff              on-chain        supply  d, w, m, q
# issuance               on-chain        supply  d, w, m, q
# supply_act_pct_1y      on-chain        supply  d, w, m, q
# stocks_to_flow         on-chain    indicators  d, w, m, q
# sopr                   on-chain    indicators  d, w, m, q
#
#                                           unit data_type  \
# id
# add_act                              addresses     Int64
# add_act_new                          addresses     Int64
# add_act_sent                         addresses     Int64
# add_act_rec                          addresses     Int64
# add_tot                              addresses     Int64
# add_pos_bal                          addresses     Int64
# add_zero_bal                         addresses     Int64
# tx_count                          transactions     Int64
# tx_rate                transactions per second   Float64
# tx_bytes_mean                            bytes   Float64
# tx_fee_mean                       transactions   Float64
# tx_fee_mean_usd                   transactions   Float64
# tfr_val                            asset units   Float64
# tfr_val_mean                       asset units   Float64
# velocity_1y                              ratio   Float64
# tx_>100k_usd                      transactions     Int64
# tx_tot                            transactions     Int64
# utxo                               asset units   Float64
# utxo_created                       asset units   Float64
# utxo_spent                         asset units   Float64
# utxo_val_created                   asset units   Float64
# utxo_val_spent                     asset units   Float64
# utxo_val_created_mean              asset units   Float64
# utxo_val_spent_mean                asset units   Float64
# hashrate                                TH/sec   Float64
# diff_last                                 none   Float64
# diff_mean                                 none   Float64
# block_height                            blocks     Int64
# block_size_mean                          bytes   Float64
# block_time_mean                        seconds   Float64
# miner_rev                          asset units   Float64
# miner_rev_usd                              usd   Float64
# miner_rev_fees                     asset units   Float64
# miner_rev_fees_usd                         usd   Float64
# miner_rev_block_rwd                asset units   Float64
# miner_rev_total_usd                        usd   Float64
# supply_circ                        asset units   Float64
# supply_ff                          asset units   Float64
# issuance                           asset units   Float64
# supply_act_pct_1y                      percent   Float64
# stocks_to_flow                           ratio   Float64
# sopr                                     ratio   Float64
#
#                                       cryptocompare_id   coinmetrics_id  \
# id
# add_act                               active_addresses        AdrActCnt
# add_act_new                              new_addresses              NaN
# add_act_sent                                       NaN    AdrActSentCnt
# add_act_rec                                        NaN     AdrActRecCnt
# add_tot                      unique_addresses_all_time              NaN
# add_pos_bal                                        NaN        AdrBalCnt
# add_zero_bal           zero_balance_addresses_all_time              NaN
# tx_count                             transaction_count            TxCnt
# tx_rate                                            NaN         TxCntSec
# tx_bytes_mean                                      NaN       TxMeanByte
# tx_fee_mean                                        NaN       FeeMeanNtv
# tx_fee_mean_usd                                    NaN       FeeMeanUSD
# tfr_val                                            NaN      TxTfrValNtv
# tfr_val_mean                average_transaction_ value  TxTfrValMeanNtv
# velocity_1y                                        NaN        VelCur1yr
# tx_>100k_usd                   large_transaction_count              NaN
# tx_tot                      transaction_count_all_time              NaN
# utxo                                               NaN          UTXOCnt
# utxo_created                                       NaN              NaN
# utxo_spent                                         NaN              NaN
# utxo_val_created                                   NaN              NaN
# utxo_val_spent                                     NaN              NaN
# utxo_val_created_mean                              NaN              NaN
# utxo_val_spent_mean                                NaN              NaN
# hashrate                                      hashrate         HashRate
# diff_last                                          NaN         DiffLast
# diff_mean                                   difficulty         DiffMean
# block_height                              block_height           BlkHgt
# block_size_mean                             block_size  BlkSizeMeanByte
# block_time_mean                             block_time       BlkIntMean
# miner_rev                                          NaN           RevNtv
# miner_rev_usd                                      NaN           RevUSD
# miner_rev_fees                                     NaN        FeeTotNtv
# miner_rev_fees_usd                                 NaN        FeeTotUSD
# miner_rev_block_rwd                                NaN              NaN
# miner_rev_total_usd                                NaN    RevAllTimeUSD
# supply_circ                             current_supply          SplyCur
# supply_ff                                          NaN           SplyFF
# issuance                                           NaN        IssTotNtv
# supply_act_pct_1y                                  NaN    SplyActPct1yr
# stocks_to_flow                                     NaN             none
# sopr                                               NaN             SOPR
#
#                       ccxt_id                        glassnode_id tiingo_id  \
# id
# add_act                   NaN              addresses/active_count       NaN
# add_act_new               NaN        addresses/new_non_zero_count       NaN
# add_act_sent              NaN             addresses/sending_count       NaN
# add_act_rec               NaN           addresses/receiving_count       NaN
# add_tot                   NaN                     addresses/count       NaN
# add_pos_bal               NaN            addresses/non_zero_count       NaN
# add_zero_bal              NaN                                 NaN       NaN
# tx_count                  NaN                  transactions/count       NaN
# tx_rate                   NaN                   transactions/rate       NaN
# tx_bytes_mean             NaN              transactions/size_mean       NaN
# tx_fee_mean               NaN                    fees/volume_mean       NaN
# tx_fee_mean_usd           NaN                    fees/volume_mean       NaN
# tfr_val                   NaN   transactions/transfers_volume_sum       NaN
# tfr_val_mean              NaN  transactions/transfers_volume_mean       NaN
# velocity_1y               NaN                 indicators/velocity       NaN
# tx_>100k_usd              NaN                                 NaN       NaN
# tx_tot                    NaN                                 NaN       NaN
# utxo                      NaN               blockchain/utxo_count       NaN
# utxo_created              NaN       blockchain/utxo_created_count       NaN
# utxo_spent                NaN         blockchain/utxo_spent_count       NaN
# utxo_val_created          NaN   blockchain/utxo_created_value_sum       NaN
# utxo_val_spent            NaN     blockchain/utxo_spent_value_sum       NaN
# utxo_val_created_mean     NaN  blockchain/utxo_created_value_mean       NaN
# utxo_val_spent_mean       NaN    blockchain/utxo_spent_value_mean       NaN
# hashrate                  NaN               mining/hash_rate_mean       NaN
# diff_last                 NaN            mining/difficulty_latest       NaN
# diff_mean                 NaN                                 NaN       NaN
# block_height              NaN             blockchain/block_height       NaN
# block_size_mean           NaN          blockchain/block_size_mean       NaN
# block_time_mean           NaN      blockchain/block_interval_mean       NaN
# miner_rev                 NaN                  mining/revenue_sum       NaN
# miner_rev_usd             NaN                  mining/revenue_sum       NaN
# miner_rev_fees            NaN                     fees/volume_sum       NaN
# miner_rev_fees_usd        NaN                     fees/volume_sum       NaN
# miner_rev_block_rwd       NaN             mining/volume_mined_sum       NaN
# miner_rev_total_usd       NaN                                 NaN       NaN
# supply_circ               NaN                      supply/current       NaN
# supply_ff                 NaN                                 NaN       NaN
# issuance                  NaN               supply/inflation_rate       NaN
# supply_act_pct_1y         NaN       supply/active_more_1y_percent       NaN
# stocks_to_flow            NaN      indicators/stock_to_flow_ratio       NaN
# sopr                      NaN                     indicators/sopr       NaN
#
#                       investpy_id dbnomics_id fred_id av-daily_id  \
# id
# add_act                       NaN         NaN     NaN         NaN
# add_act_new                   NaN         NaN     NaN         NaN
# add_act_sent                  NaN         NaN     NaN         NaN
# add_act_rec                   NaN         NaN     NaN         NaN
# add_tot                       NaN         NaN     NaN         NaN
# add_pos_bal                   NaN         NaN     NaN         NaN
# add_zero_bal                  NaN         NaN     NaN         NaN
# tx_count                      NaN         NaN     NaN         NaN
# tx_rate                       NaN         NaN     NaN         NaN
# tx_bytes_mean                 NaN         NaN     NaN         NaN
# tx_fee_mean                   NaN         NaN     NaN         NaN
# tx_fee_mean_usd               NaN         NaN     NaN         NaN
# tfr_val                       NaN         NaN     NaN         NaN
# tfr_val_mean                  NaN         NaN     NaN         NaN
# velocity_1y                   NaN         NaN     NaN         NaN
# tx_>100k_usd                  NaN         NaN     NaN         NaN
# tx_tot                        NaN         NaN     NaN         NaN
# utxo                          NaN         NaN     NaN         NaN
# utxo_created                  NaN         NaN     NaN         NaN
# utxo_spent                    NaN         NaN     NaN         NaN
# utxo_val_created              NaN         NaN     NaN         NaN
# utxo_val_spent                NaN         NaN     NaN         NaN
# utxo_val_created_mean         NaN         NaN     NaN         NaN
# utxo_val_spent_mean           NaN         NaN     NaN         NaN
# hashrate                      NaN         NaN     NaN         NaN
# diff_last                     NaN         NaN     NaN         NaN
# diff_mean                     NaN         NaN     NaN         NaN
# block_height                  NaN         NaN     NaN         NaN
# block_size_mean               NaN         NaN     NaN         NaN
# block_time_mean               NaN         NaN     NaN         NaN
# miner_rev                     NaN         NaN     NaN         NaN
# miner_rev_usd                 NaN         NaN     NaN         NaN
# miner_rev_fees                NaN         NaN     NaN         NaN
# miner_rev_fees_usd            NaN         NaN     NaN         NaN
# miner_rev_block_rwd           NaN         NaN     NaN         NaN
# miner_rev_total_usd           NaN         NaN     NaN         NaN
# supply_circ                   NaN         NaN     NaN         NaN
# supply_ff                     NaN         NaN     NaN         NaN
# issuance                      NaN         NaN     NaN         NaN
# supply_act_pct_1y             NaN         NaN     NaN         NaN
# stocks_to_flow                NaN         NaN     NaN         NaN
# sopr                          NaN         NaN     NaN         NaN
#
#                       av-forex-daily_id yahoo_id
# id
# add_act                             NaN      NaN
# add_act_new                         NaN      NaN
# add_act_sent                        NaN      NaN
# add_act_rec                         NaN      NaN
# add_tot                             NaN      NaN
# add_pos_bal                         NaN      NaN
# add_zero_bal                        NaN      NaN
# tx_count                            NaN      NaN
# tx_rate                             NaN      NaN
# tx_bytes_mean                       NaN      NaN
# tx_fee_mean                         NaN      NaN
# tx_fee_mean_usd                     NaN      NaN
# tfr_val                             NaN      NaN
# tfr_val_mean                        NaN      NaN
# velocity_1y                         NaN      NaN
# tx_>100k_usd                        NaN      NaN
# tx_tot                              NaN      NaN
# utxo                                NaN      NaN
# utxo_created                        NaN      NaN
# utxo_spent                          NaN      NaN
# utxo_val_created                    NaN      NaN
# utxo_val_spent                      NaN      NaN
# utxo_val_created_mean               NaN      NaN
# utxo_val_spent_mean                 NaN      NaN
# hashrate                            NaN      NaN
# diff_last                           NaN      NaN
# diff_mean                           NaN      NaN
# block_height                        NaN      NaN
# block_size_mean                     NaN      NaN
# block_time_mean                     NaN      NaN
# miner_rev                           NaN      NaN
# miner_rev_usd                       NaN      NaN
# miner_rev_fees                      NaN      NaN
# miner_rev_fees_usd                  NaN      NaN
# miner_rev_block_rwd                 NaN      NaN
# miner_rev_total_usd                 NaN      NaN
# supply_circ                         NaN      NaN
# supply_ff                           NaN      NaN
# issuance                            NaN      NaN
# supply_act_pct_1y                   NaN      NaN
# stocks_to_flow                      NaN      NaN
# sopr                                NaN      NaN

# %%
df = dc.search_fields(by_col='subcategory', keyword='addresses')

# %%
df
# Out:
#                                            name  \
# id
# add_act                        active addresses
# add_act_new                       new addresses
# add_act_sent              active addresses sent
# add_act_rec           active addresses received
# add_tot                     total address count
# add_pos_bal    addresses with positive balance
# add_zero_bal  addresses with zero balance count
#
#                                                     description  category  \
# id
# add_act       number of unique addresses that were active in...  on-chain
# add_act_new   number of new unique addresses that were creat...  on-chain
# add_act_sent  number of unique addresses that were active in...  on-chain
# add_act_rec   number of unique addresses that were active in...  on-chain
# add_tot       number of unique addresses in the network  at ...  on-chain
# add_pos_bal   number of unique addresses  with positive bala...  on-chain
# add_zero_bal  number of unique addresses  with zero balance ...  on-chain
#
#              subcategory        freq       unit data_type  \
# id
# add_act        addresses  d, w, m, q  addresses     Int64
# add_act_new    addresses  d, w, m, q  addresses     Int64
# add_act_sent   addresses  d, w, m, q  addresses     Int64
# add_act_rec    addresses  d, w, m, q  addresses     Int64
# add_tot        addresses  d, w, m, q  addresses     Int64
# add_pos_bal    addresses  d, w, m, q  addresses     Int64
# add_zero_bal   addresses  d, w, m, q  addresses     Int64
#
#                              cryptocompare_id coinmetrics_id ccxt_id  \
# id
# add_act                      active_addresses      AdrActCnt     NaN
# add_act_new                     new_addresses            NaN     NaN
# add_act_sent                              NaN  AdrActSentCnt     NaN
# add_act_rec                               NaN   AdrActRecCnt     NaN
# add_tot             unique_addresses_all_time            NaN     NaN
# add_pos_bal                               NaN      AdrBalCnt     NaN
# add_zero_bal  zero_balance_addresses_all_time            NaN     NaN
#
#                               glassnode_id tiingo_id investpy_id dbnomics_id  \
# id
# add_act             addresses/active_count       NaN         NaN         NaN
# add_act_new   addresses/new_non_zero_count       NaN         NaN         NaN
# add_act_sent       addresses/sending_count       NaN         NaN         NaN
# add_act_rec      addresses/receiving_count       NaN         NaN         NaN
# add_tot                    addresses/count       NaN         NaN         NaN
# add_pos_bal       addresses/non_zero_count       NaN         NaN         NaN
# add_zero_bal                           NaN       NaN         NaN         NaN
#
#              fred_id av-daily_id av-forex-daily_id yahoo_id
# id
# add_act          NaN         NaN               NaN      NaN
# add_act_new      NaN         NaN               NaN      NaN
# add_act_sent     NaN         NaN               NaN      NaN
# add_act_rec      NaN         NaN               NaN      NaN
# add_tot          NaN         NaN               NaN      NaN
# add_pos_bal      NaN         NaN               NaN      NaN
# add_zero_bal     NaN         NaN               NaN      NaN

# %%
dc.scrape_stablecoins(source='coingecko')
# Out:
#                   name     price       mkt_cap    24h_volume
# ticker
# USDT       Tether USDT  1.000000  6.757183e+10  2.336604e+10
# USDC          USD Coin  0.999651  5.185829e+10  6.006708e+09
# BUSD       Binance USD  0.999850  1.943430e+10  4.361232e+09
# DAI            Dai DAI  1.010000  6.482856e+09  5.085242e+08
# FRAX         Frax FRAX  1.000000  1.492966e+09  6.807356e+06
# ...                ...       ...           ...           ...
# JPYC          JPY Coin  0.007150           NaN  1.129000e+03
# USX         dForce USD  1.000000           NaN  3.356000e+03
# COUSD    Coffin Dollar  0.942568           NaN  3.040000e+00
# BDO        bDollar BDO  0.032552           NaN  6.360000e+02
# NZDS    NZD Stablecoin  0.607393           NaN           NaN
#
# [85 rows x 4 columns]
